# %%
import numpy as np
import pandas as pd
from sklearn import linear_model

# %%
df =  pd.read_csv('../01 Linear Regression/homeprices.csv')
df.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
x_area =  df.iloc[:,:1]
y_price = df.iloc[:,1]

# %%
model = linear_model.LinearRegression() 
model.fit(x_area,y_price)
# Out:
# LinearRegression()

# %%
model.predict([[5000]])
# Out:
# C:\Users\sdara\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
# we can use pickle to save model

# %%
import pickle

# %%
with open('model_pickle','wb') as f :
    pickle.dump(model,f)

# %%
# we can load the file like this

# %%
with open('model_pickle','rb') as f :
    mp = pickle.load(f)

# %%
mp.predict([[5000]])
# Out:
# C:\Users\sdara\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
# if we have more numpy arrays joblib is more efficient in saving models

# %%
import joblib

# %%
joblib.dump(model,'model_joblib')
# Out:
# ['model_joblib']

# %%
model_object = joblib.load('model_joblib')

# %%
model_object.predict([[5000]])
# Out:
# C:\Users\sdara\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])
