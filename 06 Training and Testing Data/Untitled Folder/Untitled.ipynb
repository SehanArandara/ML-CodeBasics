# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../carprices.csv')
data.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %% [markdown]
# - we have to split our data into test and train then we can validate and evaluate our model
# - ![image.png](attachment:96837c7e-1d85-446d-b0f5-884490f13941.png)

# %%
x = data.iloc[:,:2]
y = data.iloc[:,2]

# %%
from sklearn.model_selection import train_test_split

x_train , x_test , y_train , y_test =  train_test_split(x,y,test_size=0.3,random_state=2)

# %%
len(x_train)
# Out:
# 14

# %%
len(x_test)
# Out:
# 6

# %%
x.shape
# Out:
# (20, 2)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(x_test)
pred
# Out:
# array([25726.39937402, 30288.52050225, 15881.63588871, 22272.43206292,
#        23011.20127434, 25726.39937402])

# %%
evaluate = model.score(x_test,y_test)
evaluate
# Out:
# 0.8607340520418888

# %%
from sklearn.metrics import mean_absolute_error

mea = mean_absolute_error(y_test,pred)
mea
# Out:
# 1812.3249959461536
